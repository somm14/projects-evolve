# %% [markdown]
# # *Exploratory Data Analisys - Análisis sobre los hábitos de vida del ciudadano*
# ------

# %% [markdown]
# ## 🗒️**Bloque de contenidos:**
#
# 1. [Introducción](#Introducción)
# 2. [Carga de datos](#Carga-de-datos)

# %% [markdown]
# ## **1. Introducción**
#
# El presente notebook realiza un *Análisis Exploratorio de Datos (EDA)* sobre un conjunto de datos de salud pública procedente del **Behavioral Risk Factor Surveillance System (BRFSS)**, una encuesta anual realizada por los **Centers for Disease Control and Prevention (CDC)** de Estados Unidos. Este dataset recoge información detallada relacionada con hábitos de vida, salud física, bienestar emocional, estilos de alimentación, sueño, ejercicio físico, consumo de alcohol y presencia de determinadas enfermedades.
#
# El objetivo principal de este notebook es llevar a cabo un flujo completo y estructurado de **exploración, limpieza y visualización** básica de los datos, siguiendo el propósito del ejercicio práctico del máster. El análisis inicial permitirá comprender la estructura del dataset, evaluar su calidad, detectar problemas comunes (valores nulos, incoherencias, outliers, codificaciones irregulares) y preparar el conjunto de datos para análisis posteriores.
#
# Este trabajo se centra exclusivamente en el EDA, sin aplicar técnicas de modelado ni análisis estadístico avanzado. La intención es **desarrollar criterio y orden** en las fases fundamentales de inspección y tratamiento de datos, aplicando buenas prácticas de análisis exploratorio.
#
# A lo largo del notebook se realizarán los **siguientes pasos**:
#
# - Carga del dataset y revisión general de su estructura.
#
# - Exploración inicial: tipos de datos, valores nulos, duplicados, rangos y coherencia.
#
# - Limpieza y normalización, justificando cada decisión.
#
# - Visualizaciones básicas para comprender la distribución de variables clave.
#
# - Conclusiones exploratorias que resuman los principales hallazgos.
#
# El **objetivo final** es obtener una visión clara y ordenada del dataset, transformándolo desde su estado original hacia una versión depurada que facilite futuras tareas analíticas.
#
# Para poder iniciar este EDA, se debe plantear una serie de preguntas que alce la iniciativa y la curiosidad del análisis, planteando estas **primeras cuestiones**:
#
# - ¿Cómo se distribuyen las horas de sueño?
#
# - ¿Qué prevalencia hay de mala salud mental o física?
#
# - ¿Qué relación podría haber entre ejercicio, sueño y salud percibida?
#
# - ¿Hay diferencias según sexo o grupo de edad?

# %% [markdown]
# ---

# %% [markdown]
# ## **2. Carga de datos**
#
# ### ***2.1 Importación de módulos***

# %%
# %pwd
# Out:
# 'c:\\Users\\sorim\\Documents\\Data_Science\\Evolve\\repos\\projects-evolve\\EDA\\notebooks'

# %%
# Ajusto la ruta
# %cd ..
# Out:
# c:\Users\sorim\Documents\Data_Science\Evolve\repos\projects-evolve\EDA

# %%
from data.variables import *
from notebooks.funciones import *
import numpy as np
import pandas as pd

# %% [markdown]
# ### ***2.2 Importación de datos***

# %%
df = pd.read_sas('./data/LLCP2022.XPT', format='xport', encoding='latin1')
df
# Out:
#         _STATE  FMONTH     IDATE IMONTH IDAY IYEAR  DISPCODE       SEQNO  \
# 0          1.0     1.0  02032022     02   03  2022    1100.0  2022000001
# 1          1.0     1.0  02042022     02   04  2022    1100.0  2022000002
# 2          1.0     1.0  02022022     02   02  2022    1100.0  2022000003
# 3          1.0     1.0  02032022     02   03  2022    1100.0  2022000004
# 4          1.0     1.0  02022022     02   02  2022    1100.0  2022000005
# ...        ...     ...       ...    ...  ...   ...       ...         ...
# 445127    78.0    11.0  12192022     12   19  2022    1100.0  2022001527
# 445128    78.0    11.0  12212022     12   21  2022    1100.0  2022001528
# 445129    78.0    11.0  11292022     11   29  2022    1100.0  2022001529
# 445130    78.0    11.0  12082022     12   08  2022    1100.0  2022001530
# 445131    78.0    11.0  12142022     12   14  2022    1100.0  2022001531
#
#                 _PSU  CTELENM1  ...  _SMOKGRP  _LCSREC  DRNKANY6  \
# 0       2.022000e+09       1.0  ...       4.0      NaN       2.0
# 1       2.022000e+09       1.0  ...       4.0      NaN       2.0
# 2       2.022000e+09       1.0  ...       4.0      NaN       2.0
# 3       2.022000e+09       1.0  ...       3.0      2.0       2.0
# 4       2.022000e+09       1.0  ...       4.0      NaN       1.0
# ...              ...       ...  ...       ...      ...       ...
# 445127  2.022002e+09       NaN  ...       4.0      NaN       7.0
# 445128  2.022002e+09       NaN  ...       4.0      NaN       2.0
# 445129  2.022002e+09       NaN  ...       1.0      NaN       7.0
# 445130  2.022002e+09       NaN  ...       4.0      NaN       2.0
# 445131  2.022002e+09       NaN  ...       3.0      NaN       1.0
#
#             DROCDY4_  _RFBING6      _DRNKWK2  _RFDRHV8  _FLSHOT7  _PNEUMO3  \
# 0       5.397605e-79       1.0  5.397605e-79       1.0       1.0       2.0
# 1       5.397605e-79       1.0  5.397605e-79       1.0       2.0       2.0
# 2       5.397605e-79       1.0  5.397605e-79       1.0       NaN       NaN
# 3       5.397605e-79       1.0  5.397605e-79       1.0       9.0       9.0
# 4       1.000000e+01       1.0  1.400000e+02       1.0       NaN       NaN
# ...              ...       ...           ...       ...       ...       ...
# 445127  9.000000e+02       9.0  9.990000e+04       9.0       NaN       NaN
# 445128  5.397605e-79       1.0  5.397605e-79       1.0       NaN       NaN
# 445129  9.000000e+02       9.0  9.990000e+04       9.0       2.0       2.0
# 445130  5.397605e-79       1.0  5.397605e-79       1.0       1.0       1.0
# 445131  5.000000e+01       2.0  9.990000e+04       9.0       NaN       NaN
#
#         _AIDTST4
# 0            2.0
# 1            2.0
# 2            2.0
# 3            2.0
# 4            2.0
# ...          ...
# 445127       1.0
# 445128       1.0
# 445129       2.0
# 445130       1.0
# 445131       2.0
#
# [445132 rows x 328 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 445132 entries, 0 to 445131
# Columns: 328 entries, _STATE to _AIDTST4
# dtypes: float64(323), object(5)
# memory usage: 1.1+ GB

# %% [markdown]
# Como se puede observar, es un dataset muy complejo en el que cuenta con 445.132 filas y 328 columnas.
#
# Al tener un tiempo limitado para poder analizar todos los datos, voy a centrarme en aquellas columnas que me pueden interesar más.
#
# Gracias a que la fuente de los datos también incluye un archivo donde viene información de cada una de las variables, me quedaré con:
# - **Hábitos y estilo de vida**
#
#     - `EXERANY2` -> ¿Realiza ejercicio?
#
#     - `SLEPTIM1` -> Horas de sueño
#
#     - `SMOKE100` -> Ha fumado 100 cigarrillos en su vida
#
#     - `ALCDAY4` -> Frecuencia de consumo de alcohol
#
# - **Estrés y salud mental**
#
#     - `MENTHLTH` -> Días de mala salud mental (últimos 30 días)
#
# - **Salud física**
#
#     - `GENHLTH` -> Salud general
#
#     - `PHYSHLTH` -> Días de mala salud física
#
#     - `DIABETE4` -> Diabetes
#
#     - `CVDCRHD4` -> Enfermedad cardiovascular
#
#     - `ASTHMA3` -> Asma
#
#     - `CHCOCNC1` -> Cáncer
#
# - **Variables socio-demográficas**
#
#     - `COLGSEX1` -> Género
#
#     - `_AGEG5YR` -> Grupo de edad
#
#     - `INCOME3` -> Nivel de ingresos
#
#     - `_EDUCAG` -> Nivel educativo
#
#     - `EMPLOY1` -> Empleo
#
#     - `_STATE` -> Estado
#
#     - `_BMI5CAT` -> Categprías de IMC

# %% [markdown]
# ### ***2.3 Mapeo de las variables***
#
# Ahora que ya se ha hecho la selección de las variables que más me llaman la atención y las cuales quiero analizar, procedemos a mapear las variables ya que están codificada de manera numérica.
#
# Para que sea más automatizado el mapeo de las variables, así como sus valores (ya que vienen codificadas de manera numérica), he creado un script de python para la ayuda de la conversión.

# %%
# En primer lugar, convierto todas las variables en un único diccionario
mapeo = {}
for v in [values1, values2,values3, values4, values5, values6, values7, values8, values9, values10, values11, values12, values13, values14, values15, values16, values17, values18]:
    mapeo.update(v)

# %%
mapeo
# Out:
# {'EXERANY2': {1: 'Yes', 2: 'No', 7: 'Don’t know/Not Sure', 9: 'Refused'},
#  'SLEPTIM1': {77: 'Don’t know/Not Sure', 99: 'Refused'},
#  'SMOKE100': {1: 'Yes', 2: 'No', 7: 'Don’t know/Not Sure', 9: 'Refused'},
#  'ALCDAY4': {range(101, 200): '1 day per week',
#   range(201, 300): '2 days per week',
#   777: 'Don’t know/Not sure',
#   888: 'No drinks in past 30 days',
#   999: 'Refused'},
#  'MENTHLTH': {88: None, 77: 'Don’t know/Not sure', 99: 'Refused'},
#  'GENHLTH': {1: 'Excellent',
#   2: 'Very good',
#   3: 'Good',
#   4: 'Fair',
#   5: 'Poor',
#   7: 'Don’t know/Not Sure',
#   9: 'Refused'},
#  'PHYSHLTH': {77: 'Don’t know/Not sure', 99: 'Refused'},
#  'DIABETE4': {1: 'Yes',
#   2: 'Yes, but female told only during pregnancy',
#   3: 'No',
#   4: 'Pre-diabetes or borderline diabetes',
#   7: 'Don’t know/Not Sure',
#   9: 'Refused'},
#  'CVDCRHD4': {1: 'Yes', 2: 'No', 7: 'Don’t know/Not sure', 9: 'Refused'},
#  'ASTHMA3': {1: 'Yes', 2: 'No', 7: 'Don’t know/Not sure', 9: 'Refused'},
#  'CHCOCNC1': {1: 'Yes', 2: 'No', 7: 'Don’t know/Not sure', 9: 'Refused'},
#  'COLGSEX1': {1: 'Male', 2: 'Female'},
#  '_AGEG5YR': {1: 'Age 18 to 24',
#   2: 'Age 25 to 29',
#   3: 'Age 30 to 34',
#   4: 'Age 35 to 39',
#   5: 'Age 30 to 44',
#   6: 'Age 45 to 49',
#   7: 'Age 50 to 54',
#   8: 'Age 55 to 59',
#   9: 'Age 60 to 64',
#   10: 'Age 65 to 69',
#   11: 'Age 70 to 74',
#   12: 'Age 75 to 79',
#   13: 'Age 80 or older',
#   14: nan},
#  'INCOME3': {1: 'Less than $10,000',
#   2: '$10,000 to < $15,000',
#   3: '$15,000 to < $20,000',
#   4: '$20,000 to < $25,000',
#   5: '$25,000 to < $35,000',
#   6: '$35,000 to < $50,000',
#   7: '$50,000 to < $75,000',
#   8: '$75,000 to < $100,000',
#   9: '$100,000 to < $150,000',
#   10: '$150,000 to < $200,000',
#   11: '$200,000 or more',
#   77: 'Don’t know/Not sure',
#   99: 'Refused'},
#  '_EDUCAG': {1: 'Did not graduate High School',
#   2: 'Graduated High School',
#   3: 'Attended College or Technical School',
#   4: 'Graduated from College or Technical School',
#   9: nan},
#  'EMPLOY1': {1: 'Employed for wages',
#   2: 'Self-employed',
#   3: 'Out of work for 1 year or more',
#   4: 'Out of work for less than 1 year',
#   5: 'A homemaker',
#   6: 'A student',
#   7: 'Retired',
#   8: 'Unable to work',
#   9: 'Refused'},
#  '_STATE': {1: 'Alabama',
#   2: 'Alaska',
#   4: 'Arizona',
#   5: 'Arkansas',
#   6: 'California',
#   8: 'Colorado',
#   9: 'Connecticut',
#   10: 'Delaware',
#   11: 'District of Columbia',
#   12: 'Florida',
#   13: 'Georgia',
#   15: 'Hawaii',
#   16: 'Idaho',
#   17: 'Illinois',
#   18: 'Indiana',
#   19: 'Iowa',
#   20: 'Kansas',
#   21: 'Kentucky',
#   22: 'Louisiana',
#   23: 'Maine',
#   24: 'Maryland',
#   25: 'Massachusetts',
#   26: 'Michigan',
#   27: 'Minnesota',
#   28: 'Mississippi',
#   29: 'Missouri',
#   30: 'Montana',
#   31: 'Nebraska',
#   32: 'Nevada',
#   33: 'New Hampshire',
#   34: 'New Jersey',
#   35: 'New Mexico',
#   36: 'New York',
#   37: 'North Carolina',
#   38: 'North Dakota',
#   39: 'Ohio',
#   40: 'Oklahoma',
#   41: 'Oregon',
#   42: 'Pennsylvania',
#   44: 'Rhode Island',
#   45: 'South Carolina',
#   46: 'South Dakota',
#   47: 'Tennessee',
#   48: 'Texas',
#   49: 'Utah',
#   50: 'Vermont',
#   51: 'Virginia',
#   53: 'Washington',
#   54: 'West Virginia',
#   55: 'Wisconsin',
#   56: 'Wyoming',
#   66: 'Guam',
#   72: 'Puerto Rico',
#   78: 'Virgin Islands'},
#  '_BMI5CAT': {1: 'Underweight',
#   2: 'Normal Weight',
#   3: 'Overweight',
#   4: 'Obese'}}

# %%
# Expando los ranges
mappings = {col: ranges_expand(map_dict) for col, map_dict in mapeo.items()}
mappings
# Out:
# {'EXERANY2': {1: 'Yes', 2: 'No', 7: 'Don’t know/Not Sure', 9: 'Refused'},
#  'SLEPTIM1': {77: 'Don’t know/Not Sure', 99: 'Refused'},
#  'SMOKE100': {1: 'Yes', 2: 'No', 7: 'Don’t know/Not Sure', 9: 'Refused'},
#  'ALCDAY4': {101: '1 day per week',
#   102: '1 day per week',
#   103: '1 day per week',
#   104: '1 day per week',
#   105: '1 day per week',
#   106: '1 day per week',
#   107: '1 day per week',
#   108: '1 day per week',
#   109: '1 day per week',
#   110: '1 day per week',
#   111: '1 day per week',
#   112: '1 day per week',
#   113: '1 day per week',
#   114: '1 day per week',
#   115: '1 day per week',
#   116: '1 day per week',
#   117: '1 day per week',
#   118: '1 day per week',
#   119: '1 day per week',
#   120: '1 day per week',
#   121: '1 day per week',
#   122: '1 day per week',
#   123: '1 day per week',
#   124: '1 day per week',
#   125: '1 day per week',
#   126: '1 day per week',
#   127: '1 day per week',
#   128: '1 day per week',
#   129: '1 day per week',
#   130: '1 day per week',
#   131: '1 day per week',
#   132: '1 day per week',
#   133: '1 day per week',
#   134: '1 day per week',
#   135: '1 day per week',
#   136: '1 day per week',
#   137: '1 day per week',
#   138: '1 day per week',
#   139: '1 day per week',
#   140: '1 day per week',
#   141: '1 day per week',
#   142: '1 day per week',
#   143: '1 day per week',
#   144: '1 day per week',
#   145: '1 day per week',
#   146: '1 day per week',
#   147: '1 day per week',
#   148: '1 day per week',
#   149: '1 day per week',
#   150: '1 day per week',
#   151: '1 day per week',
#   152: '1 day per week',
#   153: '1 day per week',
#   154: '1 day per week',
#   155: '1 day per week',
#   156: '1 day per week',
#   157: '1 day per week',
#   158: '1 day per week',
#   159: '1 day per week',
#   160: '1 day per week',
#   161: '1 day per week',
#   162: '1 day per week',
#   163: '1 day per week',
#   164: '1 day per week',
#   165: '1 day per week',
#   166: '1 day per week',
#   167: '1 day per week',
#   168: '1 day per week',
#   169: '1 day per week',
#   170: '1 day per week',
#   171: '1 day per week',
#   172: '1 day per week',
#   173: '1 day per week',
#   174: '1 day per week',
#   175: '1 day per week',
#   176: '1 day per week',
#   177: '1 day per week',
#   178: '1 day per week',
#   179: '1 day per week',
#   180: '1 day per week',
#   181: '1 day per week',
#   182: '1 day per week',
#   183: '1 day per week',
#   184: '1 day per week',
#   185: '1 day per week',
#   186: '1 day per week',
#   187: '1 day per week',
#   188: '1 day per week',
#   189: '1 day per week',
#   190: '1 day per week',
#   191: '1 day per week',
#   192: '1 day per week',
#   193: '1 day per week',
#   194: '1 day per week',
#   195: '1 day per week',
#   196: '1 day per week',
#   197: '1 day per week',
#   198: '1 day per week',
#   199: '1 day per week',
#   201: '2 days per week',
#   202: '2 days per week',
#   203: '2 days per week',
#   204: '2 days per week',
#   205: '2 days per week',
#   206: '2 days per week',
#   207: '2 days per week',
#   208: '2 days per week',
#   209: '2 days per week',
#   210: '2 days per week',
#   211: '2 days per week',
#   212: '2 days per week',
#   213: '2 days per week',
#   214: '2 days per week',
#   215: '2 days per week',
#   216: '2 days per week',
#   217: '2 days per week',
#   218: '2 days per week',
#   219: '2 days per week',
#   220: '2 days per week',
#   221: '2 days per week',
#   222: '2 days per week',
#   223: '2 days per week',
#   224: '2 days per week',
#   225: '2 days per week',
#   226: '2 days per week',
#   227: '2 days per week',
#   228: '2 days per week',
#   229: '2 days per week',
#   230: '2 days per week',
#   231: '2 days per week',
#   232: '2 days per week',
#   233: '2 days per week',
#   234: '2 days per week',
#   235: '2 days per week',
#   236: '2 days per week',
#   237: '2 days per week',
#   238: '2 days per week',
#   239: '2 days per week',
#   240: '2 days per week',
#   241: '2 days per week',
#   242: '2 days per week',
#   243: '2 days per week',
#   244: '2 days per week',
#   245: '2 days per week',
#   246: '2 days per week',
#   247: '2 days per week',
#   248: '2 days per week',
#   249: '2 days per week',
#   250: '2 days per week',
#   251: '2 days per week',
#   252: '2 days per week',
#   253: '2 days per week',
#   254: '2 days per week',
#   255: '2 days per week',
#   256: '2 days per week',
#   257: '2 days per week',
#   258: '2 days per week',
#   259: '2 days per week',
#   260: '2 days per week',
#   261: '2 days per week',
#   262: '2 days per week',
#   263: '2 days per week',
#   264: '2 days per week',
#   265: '2 days per week',
#   266: '2 days per week',
#   267: '2 days per week',
#   268: '2 days per week',
#   269: '2 days per week',
#   270: '2 days per week',
#   271: '2 days per week',
#   272: '2 days per week',
#   273: '2 days per week',
#   274: '2 days per week',
#   275: '2 days per week',
#   276: '2 days per week',
#   277: '2 days per week',
#   278: '2 days per week',
#   279: '2 days per week',
#   280: '2 days per week',
#   281: '2 days per week',
#   282: '2 days per week',
#   283: '2 days per week',
#   284: '2 days per week',
#   285: '2 days per week',
#   286: '2 days per week',
#   287: '2 days per week',
#   288: '2 days per week',
#   289: '2 days per week',
#   290: '2 days per week',
#   291: '2 days per week',
#   292: '2 days per week',
#   293: '2 days per week',
#   294: '2 days per week',
#   295: '2 days per week',
#   296: '2 days per week',
#   297: '2 days per week',
#   298: '2 days per week',
#   299: '2 days per week',
#   777: 'Don’t know/Not sure',
#   888: 'No drinks in past 30 days',
#   999: 'Refused'},
#  'MENTHLTH': {88: None, 77: 'Don’t know/Not sure', 99: 'Refused'},
#  'GENHLTH': {1: 'Excellent',
#   2: 'Very good',
#   3: 'Good',
#   4: 'Fair',
#   5: 'Poor',
#   7: 'Don’t know/Not Sure',
#   9: 'Refused'},
#  'PHYSHLTH': {77: 'Don’t know/Not sure', 99: 'Refused'},
#  'DIABETE4': {1: 'Yes',
#   2: 'Yes, but female told only during pregnancy',
#   3: 'No',
#   4: 'Pre-diabetes or borderline diabetes',
#   7: 'Don’t know/Not Sure',
#   9: 'Refused'},
#  'CVDCRHD4': {1: 'Yes', 2: 'No', 7: 'Don’t know/Not sure', 9: 'Refused'},
#  'ASTHMA3': {1: 'Yes', 2: 'No', 7: 'Don’t know/Not sure', 9: 'Refused'},
#  'CHCOCNC1': {1: 'Yes', 2: 'No', 7: 'Don’t know/Not sure', 9: 'Refused'},
#  'COLGSEX1': {1: 'Male', 2: 'Female'},
#  '_AGEG5YR': {1: 'Age 18 to 24',
#   2: 'Age 25 to 29',
#   3: 'Age 30 to 34',
#   4: 'Age 35 to 39',
#   5: 'Age 30 to 44',
#   6: 'Age 45 to 49',
#   7: 'Age 50 to 54',
#   8: 'Age 55 to 59',
#   9: 'Age 60 to 64',
#   10: 'Age 65 to 69',
#   11: 'Age 70 to 74',
#   12: 'Age 75 to 79',
#   13: 'Age 80 or older',
#   14: nan},
#  'INCOME3': {1: 'Less than $10,000',
#   2: '$10,000 to < $15,000',
#   3: '$15,000 to < $20,000',
#   4: '$20,000 to < $25,000',
#   5: '$25,000 to < $35,000',
#   6: '$35,000 to < $50,000',
#   7: '$50,000 to < $75,000',
#   8: '$75,000 to < $100,000',
#   9: '$100,000 to < $150,000',
#   10: '$150,000 to < $200,000',
#   11: '$200,000 or more',
#   77: 'Don’t know/Not sure',
#   99: 'Refused'},
#  '_EDUCAG': {1: 'Did not graduate High School',
#   2: 'Graduated High School',
#   3: 'Attended College or Technical School',
#   4: 'Graduated from College or Technical School',
#   9: nan},
#  'EMPLOY1': {1: 'Employed for wages',
#   2: 'Self-employed',
#   3: 'Out of work for 1 year or more',
#   4: 'Out of work for less than 1 year',
#   5: 'A homemaker',
#   6: 'A student',
#   7: 'Retired',
#   8: 'Unable to work',
#   9: 'Refused'},
#  '_STATE': {1: 'Alabama',
#   2: 'Alaska',
#   4: 'Arizona',
#   5: 'Arkansas',
#   6: 'California',
#   8: 'Colorado',
#   9: 'Connecticut',
#   10: 'Delaware',
#   11: 'District of Columbia',
#   12: 'Florida',
#   13: 'Georgia',
#   15: 'Hawaii',
#   16: 'Idaho',
#   17: 'Illinois',
#   18: 'Indiana',
#   19: 'Iowa',
#   20: 'Kansas',
#   21: 'Kentucky',
#   22: 'Louisiana',
#   23: 'Maine',
#   24: 'Maryland',
#   25: 'Massachusetts',
#   26: 'Michigan',
#   27: 'Minnesota',
#   28: 'Mississippi',
#   29: 'Missouri',
#   30: 'Montana',
#   31: 'Nebraska',
#   32: 'Nevada',
#   33: 'New Hampshire',
#   34: 'New Jersey',
#   35: 'New Mexico',
#   36: 'New York',
#   37: 'North Carolina',
#   38: 'North Dakota',
#   39: 'Ohio',
#   40: 'Oklahoma',
#   41: 'Oregon',
#   42: 'Pennsylvania',
#   44: 'Rhode Island',
#   45: 'South Carolina',
#   46: 'South Dakota',
#   47: 'Tennessee',
#   48: 'Texas',
#   49: 'Utah',
#   50: 'Vermont',
#   51: 'Virginia',
#   53: 'Washington',
#   54: 'West Virginia',
#   55: 'Wisconsin',
#   56: 'Wyoming',
#   66: 'Guam',
#   72: 'Puerto Rico',
#   78: 'Virgin Islands'},
#  '_BMI5CAT': {1: 'Underweight',
#   2: 'Normal Weight',
#   3: 'Overweight',
#   4: 'Obese'}}

# %%
# Mapeo en el DF original
df_1 = df.copy()

for col, m in mappings.items():
    df_1[col] = df_1[col].apply(lambda x: m.get(x, x)) # Uso lambda para que me cambie aquellos valores que están en el dict para que algunos valores me lo deje como están.

# %%
cols = mappings.keys()

# %%
df_1 = df_1[cols]

# %%
# Lo guardo en csv
df_1.to_csv('./data/mapped_data.csv', index=False)

# %% [markdown]
# ## **3. Exploración inicial**
#
# ### ***3.1. Vista general***

# %% [markdown]
# Ahora que ya tenemos el dataset que queremos, lo cargamos y trabajamos sobre él.
#
# Por lo que, en primer lugar, realizaremos una vista general de los datos.

# %%
df = pd.read_csv('./data/mapped_data.csv')
df.head()
# Out:
# C:\Users\sorim\AppData\Local\Temp\ipykernel_8128\917691970.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./data/mapped_data.csv')
#   EXERANY2 SLEPTIM1 SMOKE100                    ALCDAY4 MENTHLTH    GENHLTH  \
# 0       No      8.0       No  No drinks in past 30 days      NaN  Very good
# 1       No      6.0       No  No drinks in past 30 days      NaN  Excellent
# 2      Yes      5.0       No  No drinks in past 30 days      3.0  Very good
# 3      Yes      7.0      Yes  No drinks in past 30 days      NaN  Excellent
# 4      Yes      9.0       No            2 days per week      NaN       Fair
#
#   PHYSHLTH DIABETE4 CVDCRHD4 ASTHMA3 CHCOCNC1 COLGSEX1         _AGEG5YR  \
# 0     88.0      Yes       No      No       No      NaN  Age 80 or older
# 1     88.0       No       No      No      Yes      NaN  Age 80 or older
# 2      2.0       No       No      No       No      NaN     Age 55 to 59
# 3     88.0       No       No     Yes       No      NaN              NaN
# 4      2.0       No       No      No       No      NaN     Age 30 to 44
#
#                   INCOME3                                     _EDUCAG  \
# 0                 Refused  Graduated from College or Technical School
# 1    $25,000 to < $35,000                       Graduated High School
# 2  $150,000 to < $200,000  Graduated from College or Technical School
# 3     Don’t know/Not sure                       Graduated High School
# 4    $25,000 to < $35,000        Attended College or Technical School
#
#          EMPLOY1   _STATE       _BMI5CAT
# 0        Retired  Alabama            NaN
# 1  Self-employed  Alabama     Overweight
# 2        Retired  Alabama     Overweight
# 3        Retired  Alabama  Normal Weight
# 4    A homemaker  Alabama  Normal Weight

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 445132 entries, 0 to 445131
# Data columns (total 18 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   EXERANY2  445130 non-null  object
#  1   SLEPTIM1  445129 non-null  object
#  2   SMOKE100  413355 non-null  object
#  3   ALCDAY4   404369 non-null  object
#  4   MENTHLTH  179900 non-null  object
#  5   GENHLTH   445129 non-null  object
#  6   PHYSHLTH  445127 non-null  object
#  7   DIABETE4  445129 non-null  object
#  8   CVDCRHD4  445130 non-null  object
#  9   ASTHMA3   445130 non-null  object
#  10  CHCOCNC1  445129 non-null  object
#  11  COLGSEX1  21 non-null      object
#  12  _AGEG5YR  436053 non-null  object
#  13  INCOME3   432200 non-null  object
#  14  _EDUCAG   442749 non-null  object
#  15  EMPLOY1   438936 non-null  object
#  16  _STATE    445132 non-null  object
#  17  _BMI5CAT  396326 non-null  object
# dtypes: object(18)
# memory usage: 61.1+ MB

# %% [markdown]
# Podemos observar que todas las columnas son de tipo `object` y hay nulos. Por lo que lo siguiente que realizaremos es:
#
# - Cambiar el nombre de las columnas para que sean más significativas y sepamos en todo momento sobre qué información estamos trabajando
#
# - Analizar el tipo de las columnas y cambiar si fuese necesario.
#
# - Analaizar los `NaN` y si se puede realizar alguna transformación.

# %% [markdown]
# ### ***3.2. Renombramiento de columnas***

# %%
# Renombro las columnas
name_cols = {'EXERANY2': 'ejercicio',
             'SLEPTIM1': 'sueño_h',
             'SMOKE100': 'fumar',
             'ALCDAY4': 'alcohol',
             'MENTHLTH': 'salud_mental_malos',
             'GENHLTH': 'salud_general',
             'PHYSHLTH': 'salud_fisica_mala',
             'DIABETE4': 'diabetes',
             'CVDCRHD4': 'enf_cardio',
             'ASTHMA3': 'asma',
             'CHCOCNC1': 'cancer',
             'COLGSEX1': 'genero',
             '_AGEG5YR': 'grupo_edad',
             'INCOME3': 'ingresos',
             '_EDUCAG': 'educacion',
             'EMPLOY1': 'empleo',
             '_STATE': 'estado',
             '_BMI5CAT': 'IMC'}

df.rename(columns=name_cols, inplace=True)
df.sample()
# Out:
#        ejercicio sueño_h fumar         alcohol salud_mental_malos  \
# 117555        No     6.0    No  1 day per week                NaN
#
#        salud_general salud_fisica_mala diabetes enf_cardio asma cancer genero  \
# 117555     Very good              88.0       No         No   No     No    NaN
#
#           grupo_edad              ingresos              educacion  \
# 117555  Age 18 to 24  $25,000 to < $35,000  Graduated High School
#
#                     empleo estado         IMC
# 117555  Employed for wages   Iowa  Overweight

# %% [markdown]
# ### ***3.3. Tipos de datos y primera visualización de nulos***

# %% [markdown]
# A continuación, veremos cada una de las variables y nos centraremos en la tipología de sus datos

# %%
df['ejercicio'].value_counts(dropna=False)
# Out:
# ejercicio
# Yes                    337559
# No                     106480
# Don’t know/Not Sure       724
# Refused                   367
# NaN                         2
# Name: count, dtype: int64

# %%
df['ejercicio'].dtype
# Out:
# dtype('O')

# %% [markdown]
#     Dejamos como está esta variable contando que tiene únicamente dos NaN

# %%
df['sueño_h'].value_counts(dropna=False)
# Out:
# sueño_h
# 7.0                    132927
# 8.0                    125442
# 6.0                     95880
# 5.0                     30122
# 9.0                     21210
# 4.0                     12433
# 10.0                    10459
# Don’t know/Not Sure      4792
# 3.0                      3260
# 12.0                     3004
# 2.0                      1549
# 1.0                      1154
# 11.0                      686
# Refused                   658
# 16.0                      329
# 15.0                      317
# 14.0                      295
# 18.0                      168
# 13.0                      165
# 20.0                      143
# 24.0                       52
# 17.0                       27
# 22.0                       19
# 23.0                       18
# 19.0                       16
# 21.0                        4
# NaN                         3
# Name: count, dtype: int64

# %%
df['sueño_h'].dtype
# Out:
# dtype('O')

# %% [markdown]
#     Aunque sea de tipo object, a lo mejor es mejor tratarla como una numérica. Sin embargo, debido a esos valores categóricos (Don’t know/Not Sure y Refused), lo podríamos tratar como NaN y los sumamos a los 3 valores que aparecen

# %%
df['sueño_h'].value_counts(dropna=False)[['Don’t know/Not Sure', 'Refused', np.nan]].sum()
# Out:
# np.int64(5453)

# %% [markdown]
#     Habría en total 5453 nulos en sueño_h

# %%
df['fumar'].value_counts(dropna=False)
# Out:
# fumar
# No                     245955
# Yes                    164217
# NaN                     31777
# Don’t know/Not Sure      2297
# Refused                   886
# Name: count, dtype: int64

# %%
df['fumar'].dtype
# Out:
# dtype('O')

# %% [markdown]
#     La tratamos igual que la variable 'ejercicio' aunque tiene un gran número de NaN

# %%
df['alcohol'].value_counts(dropna=False)
# Out:
# alcohol
# No drinks in past 30 days    187667
# 2 days per week              144740
# 1 day per week                66151
# NaN                           40763
# Don’t know/Not sure            3447
# Refused                        2364
# Name: count, dtype: int64

# %%
df['alcohol'].dtype
# Out:
# dtype('O')

# %% [markdown]
#     La tratamos igual que la variable 'ejercicio' y 'fumar' aunque tiene un gran número de NaN

# %%
df['salud_mental_malos'].value_counts(dropna=False)
# Out:
# salud_mental_malos
# NaN                    265232
# 30.0                    26990
# 2.0                     23785
# 5.0                     19951
# 10.0                    15414
# 3.0                     15345
# 15.0                    14519
# 1.0                     14409
# 20.0                     9150
# 4.0                      7943
# 7.0                      7844
# Don’t know/Not sure      6589
# 25.0                     3078
# 14.0                     2871
# Refused                  2475
# 6.0                      2305
# 8.0                      1749
# 12.0                     1259
# 28.0                      910
# 21.0                      549
# 29.0                      502
# 9.0                       322
# 18.0                      319
# 16.0                      280
# 17.0                      244
# 27.0                      241
# 22.0                      193
# 13.0                      169
# 24.0                      124
# 11.0                      121
# 26.0                      106
# 23.0                       97
# 19.0                       47
# Name: count, dtype: int64

# %%
df['salud_mental_malos'].dtype
# Out:
# dtype('O')

# %%
df['salud_mental_malos'].value_counts(dropna=False)[['Don’t know/Not sure', 'Refused', np.nan]].sum()
# Out:
# np.int64(274296)

# %% [markdown]
#     Esta variable también convendría tratarla como una numérica por lo que, si hacemos la misma operación que con la variable 'sueño_h', quedarían muchos valores desconocidos.

# %%
df['salud_general'].value_counts(dropna=False)
# Out:
# salud_general
# Very good              148444
# Good                   143598
# Excellent               71878
# Fair                    60273
# Poor                    19741
# Don’t know/Not Sure       810
# Refused                   385
# NaN                         3
# Name: count, dtype: int64

# %%
df['salud_general'].dtype
# Out:
# dtype('O')

# %% [markdown]
#     La tratamos igual que la variable 'ejercicio', 'fumar' y 'alcohol' teniendo bastantes NaN si sumamos los valores desconocidos

# %%
df['salud_fisica_mala'].value_counts(dropna=False)
# Out:
# salud_fisica_mala
# 88.0                   267819
# 30.0                    33082
# 2.0                     25256
# 1.0                     17250
# 3.0                     15948
# 5.0                     15315
# 10.0                    10589
# 7.0                      9348
# Don’t know/Not sure      8875
# 15.0                     8787
# 4.0                      8462
# 20.0                     5421
# 14.0                     5029
# 6.0                      2538
# 25.0                     2181
# Refused                  2047
# 8.0                      1761
# 12.0                     1111
# 21.0                     1038
# 28.0                      751
# 9.0                       411
# 29.0                      365
# 18.0                      271
# 16.0                      255
# 27.0                      188
# 17.0                      185
# 13.0                      162
# 11.0                      161
# 22.0                      140
# 24.0                      125
# 26.0                      109
# 23.0                       99
# 19.0                       48
# NaN                         5
# Name: count, dtype: int64

# %%
df['salud_fisica_mala'].value_counts(dropna=False)[['Don’t know/Not sure', 'Refused', np.nan]].sum()
# Out:
# np.int64(10927)

# %%
df['diabetes'].value_counts(dropna=False)
# Out:
# diabetes
# No                                            368722
# Yes                                            61158
# Pre-diabetes or borderline diabetes            10329
# Yes, but female told only during pregnancy      3836
# Don’t know/Not Sure                              763
# Refused                                          321
# NaN                                                3
# Name: count, dtype: int64

# %%
df['enf_cardio'].value_counts(dropna=False)
# Out:
# enf_cardio
# No                     414176
# Yes                     26551
# Don’t know/Not sure      4044
# Refused                   359
# NaN                         2
# Name: count, dtype: int64

# %%
df['asma'].value_counts(dropna=False)
# Out:
# asma
# No                     376665
# Yes                     66694
# Don’t know/Not sure      1494
# Refused                   277
# NaN                         2
# Name: count, dtype: int64

# %%
df['cancer'].value_counts(dropna=False)
# Out:
# cancer
# No                     392442
# Yes                     50269
# Don’t know/Not sure      2016
# Refused                   402
# NaN                         3
# Name: count, dtype: int64

# %%
df['genero'].value_counts(dropna=False)
# Out:
# genero
# NaN       445111
# Female        16
# Male           5
# Name: count, dtype: int64

# %% [markdown]
#     Curioso que la mayoría de las personas que se sometieron a esta encuesta no quisieron decir de qué sexo eran

# %%
df['grupo_edad'].value_counts(dropna=False)
# Out:
# grupo_edad
# Age 65 to 69       47099
# Age 60 to 64       44511
# Age 70 to 74       43472
# Age 55 to 59       36821
# Age 80 or older    36251
# Age 50 to 54       33644
# Age 75 to 79       32518
# Age 30 to 44       29942
# Age 45 to 49       28531
# Age 35 to 39       28526
# Age 18 to 24       26941
# Age 30 to 34       25807
# Age 25 to 29       21990
# NaN                 9079
# Name: count, dtype: int64

# %%
df['ingresos'].value_counts(dropna=False)
# Out:
# ingresos
# $50,000 to < $75,000      59148
# $100,000 to < $150,000    50330
# $75,000 to < $100,000     48436
# Refused                   47001
# $35,000 to < $50,000      46831
# $25,000 to < $35,000      42294
# Don’t know/Not sure       36114
# $200,000 or more          23478
# $150,000 to < $200,000    22553
# $20,000 to < $25,000      20343
# $15,000 to < $20,000      14300
# NaN                       12932
# $10,000 to < $15,000      11031
# Less than $10,000         10341
# Name: count, dtype: int64

# %%
df['educacion'].value_counts(dropna=False)
# Out:
# educacion
# Graduated from College or Technical School    187496
# Attended College or Technical School          120252
# Graduated High School                         108990
# Did not graduate High School                   26011
# NaN                                             2383
# Name: count, dtype: int64

# %%
df['empleo'].value_counts(dropna=False)
# Out:
# empleo
# Employed for wages                  186004
# Retired                             137083
# Self-employed                        38768
# Unable to work                       26737
# A homemaker                          17477
# A student                            11111
# Out of work for 1 year or more        8668
# Out of work for less than 1 year      8044
# NaN                                   6196
# Refused                               5044
# Name: count, dtype: int64

# %%
df['estado'].value_counts(dropna=False)
# Out:
# estado
# Washington              26152
# New York                17800
# Minnesota               16821
# Ohio                    16487
# Maryland                16418
# Texas                   14245
# Florida                 13393
# Wisconsin               11276
# Kansas                  11247
# Massachusetts           11029
# California              10952
# Maine                   10646
# Indiana                 10466
# Virginia                10417
# Arizona                 10185
# Michigan                10058
# South Carolina          10037
# Utah                     9826
# Connecticut              9784
# Colorado                 9365
# Georgia                  9236
# Iowa                     8949
# Vermont                  8811
# New Jersey               8209
# Hawaii                   7747
# Nebraska                 7473
# Missouri                 7438
# South Dakota             7424
# Montana                  7048
# New Hampshire            6757
# Idaho                    6280
# Rhode Island             5893
# Alaska                   5865
# Oklahoma                 5775
# Oregon                   5756
# Louisiana                5629
# Puerto Rico              5509
# Arkansas                 5309
# Tennessee                5266
# West Virginia            4981
# New Mexico               4758
# Pennsylvania             4582
# Alabama                  4506
# North Carolina           4505
# Mississippi              4239
# North Dakota             4153
# Wyoming                  4142
# Illinois                 4056
# Kentucky                 4023
# Delaware                 3987
# District of Columbia     3237
# Nevada                   3188
# Guam                     2266
# Virgin Islands           1531
# Name: count, dtype: int64

# %%
df['estado'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming', 'Guam', 'Puerto Rico',
#        'Virgin Islands'], dtype=object)

# %%
df['IMC'].value_counts(dropna=False)
# Out:
# IMC
# Overweight       139995
# Obese            132577
# Normal Weight    116976
# NaN               48806
# Underweight        6778
# Name: count, dtype: int64

# %% [markdown]
# En resumen:
#
# - Todas las variables tienen valores `NaN` por lo que antes de ver cómo transformarlas tendremos en cuenta:
#
#     - Los valores duplicados.
#
#     - Si en una misma fila hay bastantes nulos.
#
# - Con este análisis de cada variable, podemos clasificar en dos grandes grupos:
#
#     - **Variables de tipo categórica**: `ejercicio`, `fumar`, `alcohol`, `salud_general`, `diabetes`, `enf_cardio`, `asma`, `cancer`, `grupo_edad`, `ingresos` (va por rangos), `educacion`, `empleo`, `estado` y `IMC`.
#
#     - **Variables de tipo numérica**: `sueño_h`, `salud_mental_malos`, `salud_fisica_mala`.
#
# Me planteo eliminar la variable `genero` por el gran número de nulos y no aportaría mucha información al análisis.

# %% [markdown]
# ### ***3.4. Duplicados***

# %%
df.duplicated().sum()
# Out:
# np.int64(2806)

# %% [markdown]
# De 445.132 valores, únicamente existen 2.806 filas que están duplicadas.
#
# Se puede profundizar más y ver si esas filas tienen más valores nulos o no.
