# %% [markdown]
# # ***Exploratory Data Analisys - Análisis sobre los hábitos de vida del ciudadano***
# ## ➡️ **Introducción y estrategia del Análisis Exploratorio de Datos (EDA)**
# ------

# %% [markdown]
# ### 🗒️**Bloque de contenidos:**
# 1. [Presentación del Proyecto](#1-presentación-del-proyecto)
# 2. [Objetivo del EDA](#2-objetivo-del-eda)
# 3. [Descripción del dataset](#3-descripción-del-dataset)
# 4. [Metodología y organización del proyecto](#4-metodología-y-organización-del-proyecto)
# 5. [Próximos Pasos](#5-próximos-pasos)

# %% [markdown]
# ### **1. Presentación del Proyecto**
#
# Este proyecto tiene como objetivo realizar un **Análisis Exploratorio de Datos (EDA)** utilizando un dataset real procedente del **Behavioral Risk Factor Surveillance System (BRFSS)**, una de las mayores encuestas de salud pública en Estados Unidos. Este conjunto de datos recoge información detallada sobre hábitos, conductas, estilos de vida y condiciones de salud de la población adulta.
#
# El propósito del EDA no es realizar un análisis estadístico profundo, sino **comprender la estructura, calidad y características del dataset**, identificar posibles problemas en los datos y preparar un conjunto limpio y listo para futuros análisis.
#
# En este caso, el enfoque principal estará relacionado con:
#
# - Calidad de vida y salud percibida
# - Hábitos relacionados con el bienestar físico y mental
# - Factores de estilo de vida (ejercicio, sueño, tabaco, alcohol)
# - Variables relacionadas con enfermedades físicas o crónicas
#
# Este tipo de análisis permite explorar cómo los hábitos cotidianos pueden relacionarse con el bienestar general y la salud de las personas encuestadas.

# %% [markdown]
# ### **2. Objetivo del EDA**
# El objetivo general es aplicar un proceso completo y ordenado de EDA, siguiendo estas **etapas fundamentales**:
#
# - Carga del dataset
# - Exploración preliminar
# - Descodificación y mapeo de variables
# - Análisis descriptivo inicial
# - Limpieza de datos
# - Visualizaciones básicas y relaciones entre variables
# - Conclusiones exploratorias
#
# El enfoque se mantiene en la **calidad del proceso**, la claridad y la correcta documentación de cada etapa.
#
#
# ### **1. Introducción**
#
# El presente notebook realiza un *Análisis Exploratorio de Datos (EDA)* sobre un conjunto de datos de salud pública procedente del **Behavioral Risk Factor Surveillance System (BRFSS)**, una encuesta anual realizada por los **Centers for Disease Control and Prevention (CDC)** de Estados Unidos. Este dataset recoge información detallada relacionada con hábitos de vida, salud física, bienestar emocional, estilos de alimentación, sueño, ejercicio físico, consumo de alcohol y presencia de determinadas enfermedades.
#
# El objetivo principal de este notebook es llevar a cabo un flujo completo y estructurado de **exploración, limpieza y visualización** básica de los datos, siguiendo el propósito del ejercicio práctico del máster. El análisis inicial permitirá comprender la estructura del dataset, evaluar su calidad, detectar problemas comunes (valores nulos, incoherencias, outliers, codificaciones irregulares) y preparar el conjunto de datos para análisis posteriores.
#
# Este trabajo se centra exclusivamente en el EDA, sin aplicar técnicas de modelado ni análisis estadístico avanzado. La intención es **desarrollar criterio y orden** en las fases fundamentales de inspección y tratamiento de datos, aplicando buenas prácticas de análisis exploratorio.
#
# A lo largo del notebook se realizarán los **siguientes pasos**:
#
# - Carga del dataset y revisión general de su estructura.
#
# - Exploración inicial: tipos de datos, valores nulos, duplicados, rangos y coherencia.
#
# - Limpieza y normalización, justificando cada decisión.
#
# - Visualizaciones básicas para comprender la distribución de variables clave.
#
# - Conclusiones exploratorias que resuman los principales hallazgos.
#
# El **objetivo final** es obtener una visión clara y ordenada del dataset, transformándolo desde su estado original hacia una versión depurada que facilite futuras tareas analíticas.
#
# Para poder iniciar este EDA, se debe plantear una serie de preguntas que alce la iniciativa y la curiosidad del análisis, planteando estas **primeras cuestiones**:
#
# - ¿Cómo se distribuyen las horas de sueño?
# - ¿Qué prevalencia hay de mala salud mental o física?
# - ¿Qué relación podría haber entre ejercicio, sueño y salud percibida?
# - ¿Hay diferencias según sexo o grupo de edad?

# %% [markdown]
# ### **3. Descripción del dataset**
# El dataset incluye miles de registros y numerosas variables relacionadas con aspectos como:
#
# - Estado de salud percibido
# - Horas de sueño
# - Actividad física
# - Consumo de alcohol y tabaco
# - Presencia de enfermedades crónicas
# - Salud mental
# - Factores demográficos
#
# Este volumen y variedad permiten explorar comportamientos de salud a nivel poblacional, detectar patrones y preparar datos para posteriores análisis.

# %% [markdown]
# ### **4. Metodología y organización del proyecto**
# Debido a la complejidad del dataset, el trabajo se ha dividido en **varios notebooks independientes**, cada uno centrado en una parte concreta del proceso, lo que facilita la organización y la revisión.
#
# A continuación se muestra la estructura del proyecto:
#
#
# - **Notebook 00 — Introducción y Estrategia (este notebook)**
#
# Presenta el objetivo, el contexto y la organización del EDA.
#
# - **Notebook 01 — Mapeo y Descodificación del Dataset Crudo**
#
# Aplicación de diccionarios, decodificación de categorías y limpieza inicial de valores representados por códigos numéricos.
#
# - **Notebook 02 — Exploración Inicial del Dataset Descodificado**
#
# Primeros análisis descriptivos, distribución de variables, análisis de nulos y detección de incoherencias.
#
# - **Notebook 03 — Limpieza del Dataset**
#
# Tratamiento de nulos, normalización de categorías, conversión de tipos y eliminación de duplicados.
#
# - **Notebook 04 — Visualizaciones y Relaciones Entre Variables**
#
# Gráficos básicos y relaciones relevantes entre variables del dataset.
#
# - **Notebook 05 — Conclusiones del EDA**
#
# Resumen del análisis, hallazgos más relevantes y posibles líneas futuras de trabajo.

# %% [markdown]
# ### **5. Próximos Pasos**
# El siguiente cuaderno, [Notebook 01](./01_Mapeo_descodificacion.ipynb), estará dedicado íntegramente al mapeo y descodificación del dataset crudo, para convertir los códigos numéricos en categorías legibles y prepararlo para la exploración.

# %% [markdown]
# -------
